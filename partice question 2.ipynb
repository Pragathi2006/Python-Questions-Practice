# %%
#write a program to print the greatset of given three numbers
a=int(input())
b=int(input())
c=int(input())
if a>b:
    print("a is greatest number")
elif b>c:
    print("b is greatest number")
else:
    print("c is greatest number")
# Out:
#  11
#  05
#  08
# a is greatest number

# %%
#write the program to find the second greatset of three numbers
a=int(input())
b=int(input())
c=int(input())
if a>b:
    print("a is greatest number",a)
elif c<a:
    print("c is greatest number",c)
else:
    print("b is greatest number",b)
# Out:
#  10
#  20
#  30
# b is greatest number 20

# %%
#write a program to find the smallest of given four numbers
a=int(input("enter a number:"))
b=int(input("enter a number:"))
c=int(input("enter a number:"))
d=int(input("enter a number:"))
if a<b:
    print("a is the smallest")
elif c>a:
    print("c is the  smallest")
elif b<c:
    print("b is the smallest")
else:
    print("d is the smallest")
# Out:
# enter a number: 20
# enter a number: 30
# enter a number: 40
# enter a number: 50
# a is the smallest

# %%
#write a program to find whether the given number is positive or negative
a=int(input())
if a>0:
    print("a is positive")
else:
    print("a is negative")
# Out:
#  56
# a is positive

# %%
#your task is to write a program to find whether the given yesr is leap year or not
a=int(input())
if ((a%400==0 )or( a%100!=0) and (a%4==0)):
   print("leap year")
else:
   print("not leap year")
# Out:
#  2100
# not leap year

# %%
#program to check whether the integer is a perfect square
import math
num=int(input())
sqrt_num=math.sqrt(num)
if sqrt_num.is_integer():
    print("yes")
else:
    print("no")
# Out:
#  49
# yes

# %%
#write a program  to check whether the given character is vowel or consonat
ch = input()
if ch in ('aeiouAEIOU'):
    print("Vowel")
elif ch.isalpha():
    print("Consonant")
else:
    print("Not an alphabet")
# Out:
#  A
# Vowel

# %%
#write a program to find the smallest of given four numbers
#input four numbers
a=int(input("enter the first number"))
b=int(input("enter the second number"))
c=int(input("enter the thrid number"))
d=int(input("enter the fourth number"))
e=[a,b,c,d]
e.sort()
print("the smallest number is:",e[0])
# Out:
# enter the first number 1
# enter the second number 2
# enter the thrid number 3
# enter the fourth number 4
# the smallest number is: 1

# %%
#Write a program to find the quadrant in which the given x and y coordinates are present in a graph
x = int(input())
y = int(input())
if x == 0 and y == 0:
    print("Origin")
elif x > 0 and y > 0:
    print("Ist Quadrant")
elif x < 0 and y > 0:
    print("IInd Quadrant")
elif x < 0 and y < 0:
    print("IIIrd Quadrant")
elif x > 0 and y < 0:
    print("IVth Quadrant")
elif x==0 and y>0:
    print("y is on positvie axis")
elif x==0 and y<0:
    print("y is on negative axis")
elif y==0 and x>0:
    print("x is on positive axis")
elif y==0 and x<0:
    print("x is on negative axis")
# Out:
#  0
#  2
# y is on positvie axis

# %%
#exercise 3:3rd program:-conversion of days into years,weeks,months
days=373 #numbers of days correspondas
years=days//365 #converstion of days into years
weeks=(days%365)//7 #converstion of days into  weeks
months=(days%365)%7 #converstion of days into  months
print(years,weeks,months) #printing the statement
# Out:
# 1 1 1

# %%
#exercise 3:7th program:-Write a program to reverse a 3-digit number
num=456 #consist of integer
reversed_num=int(str(num)[::-1]) #reverse of 3-digit number
print(reversed_num) #printing the statement
# Out:
# 654

# %%
#exercise 3:8th program:-write a program to calculate the body mass index(BMI)
weight=50 #weight in kg
height=1.6 #height in meters
praga=weight/(height**2) #which height and weight calculated in kilometers and meters squared
print(round(praga,2)) #printing the statement
# Out:
# 19.53
